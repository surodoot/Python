# %% [markdown]
# <a href="https://colab.research.google.com/github/surodoot/Python/blob/main/High_School/High_school_Bigdata_Class_Lecture_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
series = pd.Series([1, 3, 4, np.nan, 6, 8])
series
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

df = pd.read_csv('/content/3304-노영래-데이터셋.csv')
df
# Out:
#      temp  high  low  hum  low hum  rain  high rain  wind  high wind  case
# 0     2.1   5.8 -2.0   56       14   0.4       13.5   2.8       17.5   103
# 1     2.9   7.1 -1.6   77       35   0.6        5.9   1.0       13.6   107
# 2     2.9   8.0 -2.1   70       31   0.0        0.3   1.7       11.9   130
# 3    -1.5   3.7 -6.9   52       13   0.0        0.0   1.5        9.2   107
# 4    -3.9   0.7 -8.0   38        7   0.0        1.0   2.7       15.9   123
# ..    ...   ...  ...  ...      ...   ...        ...   ...        ...   ...
# 360   4.3   8.5 -0.7   72       28   2.0       35.2   1.8       12.0    85
# 361   3.8  10.6 -1.3   68       14   0.0        0.5   1.3        9.8   122
# 362   3.6   9.8 -0.9   64       11   0.0        0.5   1.7       10.2   107
# 363   5.5  11.3  0.4   76       33   0.0        0.9   1.6       13.0    95
# 364   3.2   9.6 -1.5   76       27   0.0        0.0   1.2        9.5   100
#
# [365 rows x 10 columns]

# %%
df['rain'].plot( kind = 'bar', color = ( 'b', 'darkorange', 'g', 'r', 'm'))

# %%
df.loc[180:185]
# Out:
#      temp  high   low  hum  low hum  rain  high rain  wind  high wind  case
# 180  25.4  29.8  22.9   86       33  20.7      146.5   1.6       12.7   100
# 181  25.6  29.1  23.5   86       39  29.4      134.4   2.6       12.5   108
# 182  25.6  28.8  23.3   87       47  23.3      132.1   2.1       11.4    84
# 183  25.3  29.0  22.6   80       32   4.0       26.6   1.8       12.7    78
# 184  25.3  30.4  20.8   74       25   0.3       11.3   1.6        7.0    87
# 185  23.9  28.6  20.4   78       30   5.2       67.4   1.4        9.8    75

# %%
print(df['rain'].loc[182])  #rain 열에서 182번째 행
print(df.loc[182, 'rain'])  #182번째 행에서 rain 열
# Out:
# 23.3
# 23.3
